# %%
# %pip install pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Dataset
#
# ### Subtask:
# Load the 'datos_casas_india.csv' file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# I need to load the 'datos_casas_india.csv' file into a pandas DataFrame named `df_houses` and display its first few rows to verify the loading process.

# %%
diccionario = pd.read_csv('/content/datasets/datos_casas_india.csv')
df1 = pd.DataFrame(diccionario)
df1
# Out:
#                     house_type   house_size            location   city  \
# 0       1 RK Studio Apartment     400 sq ft             Kalkaji  Delhi
# 1       1 RK Studio Apartment     400 sq ft   Mansarover Garden  Delhi
# 2     2 BHK Independent Floor     500 sq ft         Uttam Nagar  Delhi
# 3     3 BHK Independent House   1,020 sq ft          Model Town  Delhi
# 4             2 BHK Apartment     810 sq ft    Sector 13 Rohini  Delhi
# ...                        ...          ...                 ...    ...
# 4995              4 BHK Villa   5,896 sq ft        Sunder Nagar  Delhi
# 4996  5 BHK Independent House   6,521 sq ft        Sunder Nagar  Delhi
# 4997  3 BHK Independent Floor   1,855 sq ft  New Friends Colony  Delhi
# 4998  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
# 4999  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
#
#        latitude  longitude    price currency  numBathrooms  numBalconies  \
# ...

# %%
# Crear unas mascara y filtrar precio >= 10000
mask = df1["price"] >= 10000
print("Casas con precio >= 10000:")
print(df1[mask])
# Out:
# Casas con precio >= 10000:
#                     house_type   house_size            location   city  \
# 0       1 RK Studio Apartment     400 sq ft             Kalkaji  Delhi
# 1       1 RK Studio Apartment     400 sq ft   Mansarover Garden  Delhi
# 3     3 BHK Independent House   1,020 sq ft          Model Town  Delhi
# 4             2 BHK Apartment     810 sq ft    Sector 13 Rohini  Delhi
# 5             3 BHK Apartment     750 sq ft           DLF Farms  Delhi
# ...                        ...          ...                 ...    ...
# 4995              4 BHK Villa   5,896 sq ft        Sunder Nagar  Delhi
# 4996  5 BHK Independent House   6,521 sq ft        Sunder Nagar  Delhi
# 4997  3 BHK Independent Floor   1,855 sq ft  New Friends Colony  Delhi
# 4998  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
# 4999  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
#
#        latitude  longitude    price currency  numBathrooms  numBalconies  \
# ...

# %%
# usamos la mascara invertida para encontrar valores inferiores a 10,000
menores = df1["mask:"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mask:'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-368/4278781637.py in <cell line: 0>()
# ...
